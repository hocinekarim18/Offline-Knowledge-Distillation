# %% [markdown]
# ## Bibiliothèque

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from resnet import resnet_layer, resnet_v1, resnet_v2
from Distiller import Distiller_AdaIn, Distiller
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import time

# %matplotlib inline
seed = tf.random.set_seed(10)
# Out:
# 2022-06-08 16:23:48.909406: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-08 16:23:48.909452: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Utils

# %%
def plot_hist_kd(hist, figname):
    #History
    plt.figure(figsize=(20,7))
    plt.subplot(121)
    plt.plot(hist.history['sparse_categorical_accuracy'], label = "train accur")
    plt.plot(hist.history['val_sparse_categorical_accuracy'], label = "Val accur")
    
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title("Accuracy")
    plt.grid()
    plt.legend()


    plt.subplot(122)
    plt.plot(hist.history['student_loss'], label = "student Loss")
    plt.plot(hist.history['val_student_loss'], label = "Val loss")
    plt.xlabel('Epochs')
    plt.ylabel('Student Loss')
    plt.title("Loss")
    plt.grid()
    plt.legend()
    
    plt.savefig(figname)
    
    plt.show()

# %% [markdown]
# ## Loading cifar10 Dataset

# %%
print("================ Data Loading ================")
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Data shapes
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
print("")
# Out:
# ================ Data Loading ================
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)
# y_train shape: (50000, 1)
# y_test shape: (10000, 1)

# %% [markdown]
# ## Loading Resnet26 Teacher model

# %%
print("")
print("================ Loading teacher model ================")
teacher = tf.keras.models.load_model("Resnet26_from_logits")
print("Evaluation of Teacher model!")
teacher.evaluate(x_test, y_test)
print("")
# Out:
# ================ Loading teacher model ================
# 2022-06-08 16:24:01.096025: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-08 16:24:01.096070: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-08 16:24:01.096118: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (big26): /proc/driver/nvidia/version does not exist
# 2022-06-08 16:24:01.097812: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Evaluation of Teacher model!
# 313/313 [==============================] - 13s 38ms/step - loss: 0.5328 - sparse_categorical_accuracy: 0.9054

# %% [markdown]
# ## Creating a data augmentation process

# %%
print("================ Building dataGen ================")
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zca_epsilon=1e-06,
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
)

datagen.fit(x_train)
# Out:
# ================ Building dataGen ================

# %% [markdown]
# ## Building a preprocessing routine

# %%
print(" ============== Adding preprocessing layers ===============")
preprocessing = tf.keras.Sequential([
    tf.keras.layers.RandomCrop(32, 32, seed= seed),
    tf.keras.layers.RandomFlip(mode="horizontal", seed= seed),

])
# Out:
#  ============== Adding preprocessing layers ===============

# %% [markdown]
# ## Building Resnet8 Student model

# %%
print("============== Building Student Network Resnet8 ! =============")

student = resnet_v1(input_shape=(32, 32, 3), depth= 8)

student = tf.keras.Sequential([
    preprocessing,
    student,   
])



student_scratch = tf.keras.models.clone_model(student)

print("")
# Out:
# ============== Building Student Network Resnet8 ! =============

# %% [markdown]
# ## Building callbacks

# %%
model_save = tf.keras.callbacks.ModelCheckpoint(
    "/callback/callback_save",
    monitor='val_student_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto',
    save_freq='epoch',
    options=None,
    initial_value_threshold=None,
)

lr_reduce = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_student_loss',
    factor=0.1,
    patience=10,
    verbose=1,
    mode='min',
    
    min_delta=0.0001,
    cooldown=0,
    min_lr=0.000001,
)

lr_reduce2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=10,
    verbose=1,
    mode='min',
    
    min_delta=0.0001,
    cooldown=0,
    min_lr=0.000001,
)

# %% [markdown]
# ## Scratch Training

# %%
student_scratch = resnet_v2(input_shape=(32, 32, 3), depth= 8)

student_scratch = tf.keras.Sequential([
    preprocessing,
    student_scratch,   
])

# %%
BATCH_SIZE = 32
EPOCHS = 100
lr = 0.1

NAME = f"Resnet8_scratch_with_callbacks"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir = f"logs3/{NAME}", 
                                                 histogram_freq = 1)


student_scratch.compile(
        optimizer = tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9),
        metrics = [tf.keras.metrics.SparseCategoricalAccuracy()],
        loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        )

    # Train and evaluate on data.
hist = student_scratch.fit(x_train, y_train, 
      batch_size = BATCH_SIZE,
      epochs=EPOCHS,
      steps_per_epoch = len(x_train)/BATCH_SIZE,
      validation_data =(x_test, y_test),
      workers =40,
      use_multiprocessing= True,
      callbacks = [lr_reduce2, tensorboard],
      )


student_scratch.evaluate(x_test, y_test)

print("")

print("End !")

# %% [markdown]
# ## Knowledge distillation

# %%
student = resnet_v2(input_shape=(32, 32, 3), depth= 8)
    student = tf.keras.Sequential([
        preprocessing,
        student,   
    ])

# %%
BATCH_SIZE = 32
EPOCHS = 100
T = [5, 10, 15, 20, 25, 30, 35, 40, 100]
lr = 0.1

# %%
for t in T:
    # Configuration du tensorboard
    NAME = f"Resnet8_kd_alpha_0.1_temp_{t}"
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir = f"logs3/{NAME}", histogram_freq = 1)
    
    # Création du resnet 8
    student_test = tf.keras.models.clone_model(student)

    # Création de l'objet Distiller
    dist = Distiller(teacher, student_test)
    dist.compile(
        optimizer = tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9),
        metrics = [tf.keras.metrics.SparseCategoricalAccuracy()],
        distillation_loss_fn = tf.keras.losses.KLDivergence(),
        student_loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        alpha = 0.1,
        temperature = t)

    # Train and evaluate on data.
    hist = dist.fit(x_train, y_train, 
          batch_size = BATCH_SIZE,
          epochs=EPOCHS,
          steps_per_epoch = len(x_train)/BATCH_SIZE,
          validation_data =(x_test, y_test),
          workers =40,
          use_multiprocessing= True,
          callbacks = [lr_reduce, tensorboard],
          )


    dist.evaluate(x_test, y_test)
    print("")

    print(" =============== History Plot ===============")
    plot_hist_kd(hist, f"Resnet8_kd_alpha_0.1_temp_{t}.png")


    print("Saving model ")
    student_test.save(f"Resnet8_kd_alpha_0.1_temp_{t}")
    print("Saving Done !")

    print("Saving Weights ")
    student_test.save_weights(f"w_resnet8_alpha_0.1_temp{t}.h5")
    print("Saving Done !")
    print("")

    print("End !")
# Out:
# Epoch 1/100
# 1562/1562 [==============================] - 74s 46ms/step - sparse_categorical_accuracy: 0.4677 - student_loss: 2.0668 - Dist_loss: 1.0909 - loss: 1.1885 - val_sparse_categorical_accuracy: 0.4960 - val_student_loss: 1.4878 - lr: 0.1000
# Epoch 2/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0
100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9414 - student_loss: 0.2008 - Dist_loss: 0.0960 - loss: 0.1065 - val_sparse_categorical_accuracy: 0.8546 - val_student_loss: 1.5020 - lr: 1.0000e-03
# Epoch 49/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.9409 - student_loss: 0.2005 - Dist_loss: 0.0958 - loss: 0.1062 - val_sparse_categorical_accuracy: 0.8552 - val_student_loss: 1.4922 - lr: 1.0000e-03
# Epoch 50/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9425 - student_loss: 0.1967 - Dist_loss: 0.0956 - loss: 0.1057 - val_sparse_categorical_accuracy: 0.8551 - val_student_loss: 1.4995 - lr: 1.0000e-03
# Epoch 51/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.9414 - student_loss: 0.1979 - Dist_loss: 0.0956 - loss: 0.1058 - val_sparse_categorical_accuracy: 0.8544 - val_student_loss: 1.4982 - lr: 1.0000e-03
# Epoch 52/100
# 1563/1562 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.9424 - student_loss: 0.1973 - Dist_loss: 0.0957 - loss: 0.1059
# Epoch 52: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.9424 - student_loss: 0.1972 - Dist_loss: 0.0957 - loss: 0.1059 - val_sparse_categorical_accuracy: 0.8540 - val_student_loss: 1.4988 - lr: 1.0000e-03
# Epoch 53/100
# 1562/1562 [==============================] - 73s 46ms/step - sparse_categorical_accuracy: 0.9408 - student_loss: 0.2028 - Dist_loss: 0.0961 - loss: 0.1068 - val_sparse_categorical_accuracy: 0.8540 - val_student_loss: 1.4994 - lr: 1.0000e-04
# Epoch 54/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9405 - student_loss: 0.2054 - Dist_loss: 0.0961 - loss: 0.1071 - val_sparse_categorical_accuracy: 0.8546 - val_student_loss: 1.5019 - lr: 1.0000e-04
# Epoch 55/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.9421 - student_loss: 0.2000 - Dist_loss: 0.0958 - loss: 0.1062 - val_sparse_categorical_accuracy: 0.8545 - val_student_loss: 1.4983 - lr: 1.0000e-04
# Epoch 56/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.9402 - student_loss: 0.2016 - Dist_loss: 0.0958 - loss: 0.1064 - val_sparse_categorical_accuracy: 0.8547 - val_student_loss: 1.4957 - lr: 1.0000e-04
# Epoch 57/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9409 - student_loss: 0.1996 - Dist_loss: 0.0958 - loss: 0.1061 - val_sparse_categorical_accuracy: 0.8547 - val_student_loss: 1.5008 - lr: 1.0000e-04
# Epoch 58/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.9408 - student_loss: 0.1997 - Dist_loss: 0.0958 - loss: 0.1062 - val_sparse_categorical_accuracy: 0.8547 - val_student_loss: 1.4993 - lr: 1.0000e-04
# Epoch 59/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9401 - student_loss: 0.2022 - Dist_loss: 0.0954 - loss: 0.1061 - val_sparse_categorical_accuracy: 0.8546 - val_student_loss: 1.4999 - lr: 1.0000e-04
# Epoch 60/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9410 - student_loss: 0.1993 - Dist_loss: 0.0956 - loss: 0.1060 - val_sparse_categorical_accuracy: 0.8547 - val_student_loss: 1.5017 - lr: 1.0000e-04
# Epoch 61/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9428 - student_loss: 0.1957 - Dist_loss: 0.0957 - loss: 0.1057 - val_sparse_categorical_accuracy: 0.8539 - val_student_loss: 1.4945 - lr: 1.0000e-04
# Epoch 62/100
# 1562/1562 [============================>.] - ETA: 0s - sparse_categorical_accuracy: 0.9411 - student_loss: 0.2019 - Dist_loss: 0.0958 - loss: 0.1064
# Epoch 62: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9411 - student_loss: 0.2018 - Dist_loss: 0.0958 - loss: 0.1064 - val_sparse_categorical_accuracy: 0.8548 - val_student_loss: 1.4946 - lr: 1.0000e-04
# Epoch 63/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9412 - student_loss: 0.1976 - Dist_loss: 0.0956 - loss: 0.1058 - val_sparse_categorical_accuracy: 0.8545 - val_student_loss: 1.4968 - lr: 1.0000e-05
# Epoch 64/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9420 - student_loss: 0.1982 - Dist_loss: 0.0954 - loss: 0.1057 - val_sparse_categorical_accuracy: 0.8545 - val_student_loss: 1.4967 - lr: 1.0000e-05
# Epoch 65/100
# 1562/1562 [==============================] - 73s 47ms/step - sparse_categorical_accuracy: 0.9415 - student_loss: 0.2017 - Dist_loss: 0.0957 - loss: 0.1063 - val_sparse_categorical_accuracy: 0.8545 - val_student_loss: 1.5020 - lr: 1.0000e-05
# Epoch 66/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9414 - student_loss: 0.2007 - Dist_loss: 0.0958 - loss: 0.1063 - val_sparse_categorical_accuracy: 0.8541 - val_student_loss: 1.4943 - lr: 1.0000e-05
# Epoch 67/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9402 - student_loss: 0.2036 - Dist_loss: 0.0957 - loss: 0.1065 - val_sparse_categorical_accuracy: 0.8549 - val_student_loss: 1.4984 - lr: 1.0000e-05
# Epoch 68/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9415 - student_loss: 0.2007 - Dist_loss: 0.0958 - loss: 0.1063 - val_sparse_categorical_accuracy: 0.8551 - val_student_loss: 1.4997 - lr: 1.0000e-05
# Epoch 69/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9408 - student_loss: 0.1987 - Dist_loss: 0.0954 - loss: 0.1058 - val_sparse_categorical_accuracy: 0.8545 - val_student_loss: 1.4983 - lr: 1.0000e-05
# Epoch 70/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.9418 - student_loss: 0.1958 - Dist_loss: 0.0951 - loss: 0.1052 - val_sparse_categorical_accuracy: 0.8542 - val_student_loss: 1.5007 - lr: 1.0000e-05
# Epoch 71/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9412 - student_loss: 0.2004 - Dist_loss: 0.0960 - loss: 0.1064 - val_sparse_categorical_accuracy: 0.8551 - val_student_loss: 1.4980 - lr: 1.0000e-05
# Epoch 72/100
# 1562/1562 [============================>.] - ETA: 0s - sparse_categorical_accuracy: 0.9423 - student_loss: 0.1972 - Dist_loss: 0.0951 - loss: 0.1053
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9423 - student_loss: 0.1969 - Dist_loss: 0.0951 - loss: 0.1053 - val_sparse_categorical_accuracy: 0.8541 - val_student_loss: 1.4978 - lr: 1.0000e-05
# Epoch 73/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.9422 - student_loss: 0.2013 - Dist_loss: 0.0958 - loss: 0.1064 - val_sparse_categorical_accuracy: 0.8551 - val_student_loss: 1.4998 - lr: 1.0000e-06
# Epoch 74/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.9415 - student_loss: 0.1984 - Dist_loss: 0.0957 - loss: 0.1059 - val_sparse_categorical_accuracy: 0.8545 - val_student_loss: 1.4976 - lr: 1.0000e-06
# Epoch 75/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9413 - student_loss: 0.1998 - Dist_loss: 0.0959 - loss: 0.1063 - val_sparse_categorical_accuracy: 0.8543 - val_student_loss: 1.4930 - lr: 1.0000e-06
# Epoch 76/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9426 - student_loss: 0.1940 - Dist_loss: 0.0956 - loss: 0.1054 - val_sparse_categorical_accuracy: 0.8549 - val_student_loss: 1.4976 - lr: 1.0000e-06
# Epoch 77/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9416 - student_loss: 0.1969 - Dist_loss: 0.0953 - loss: 0.1055 - val_sparse_categorical_accuracy: 0.8549 - val_student_loss: 1.5006 - lr: 1.0000e-06
# Epoch 78/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.9427 - student_loss: 0.1954 - Dist_loss: 0.0955 - loss: 0.1055 - val_sparse_categorical_accuracy: 0.8544 - val_student_loss: 1.5041 - lr: 1.0000e-06
# Epoch 79/100
# ...
# Epoch 42/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.8937 - student_loss: 0.3126 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8251 - val_student_loss: 1.4674 - lr: 1.0000e-04
# Epoch 43/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.8948 - student_loss: 0.3100 - Dist_loss: 0.0030 - loss: 0.0337 - val_sparse_categorical_accuracy: 0.8259 - val_student_loss: 1.4645 - lr: 1.0000e-04
# Epoch 44/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8939 - student_loss: 0.3127 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8252 - val_student_loss: 1.4645 - lr: 1.0000e-04
# Epoch 45/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8935 - student_loss: 0.3140 - Dist_loss: 0.0030 - loss: 0.0341 - val_sparse_categorical_accuracy: 0.8256 - val_student_loss: 1.4651 - lr: 1.0000e-04
# Epoch 46/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8931 - student_loss: 0.3125 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8255 - val_student_loss: 1.4650 - lr: 1.0000e-04
# Epoch 47/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.8925 - student_loss: 0.3147 - Dist_loss: 0.0030 - loss: 0.0342 - val_sparse_categorical_accuracy: 0.8259 - val_student_loss: 1.4650 - lr: 1.0000e-04
# Epoch 48/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.8928 - student_loss: 0.3140 - Dist_loss: 0.0030 - loss: 0.0341 - val_sparse_categorical_accuracy: 0.8253 - val_student_loss: 1.4677 - lr: 1.0000e-04
# Epoch 49/100
# 1563/1562 [==============================] - ETA: 0s - sparse_categorical_accuracy: 0.8929 - student_loss: 0.3138 - Dist_loss: 0.0030 - loss: 0.0341
# Epoch 49: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8929 - student_loss: 0.3137 - Dist_loss: 0.0030 - loss: 0.0341 - val_sparse_categorical_accuracy: 0.8248 - val_student_loss: 1.4659 - lr: 1.0000e-04
# Epoch 50/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8919 - student_loss: 0.3145 - Dist_loss: 0.0030 - loss: 0.0341 - val_sparse_categorical_accuracy: 0.8254 - val_student_loss: 1.4666 - lr: 1.0000e-05
# Epoch 51/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8941 - student_loss: 0.3104 - Dist_loss: 0.0030 - loss: 0.0337 - val_sparse_categorical_accuracy: 0.8254 - val_student_loss: 1.4643 - lr: 1.0000e-05
# Epoch 52/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8940 - student_loss: 0.3090 - Dist_loss: 0.0030 - loss: 0.0336 - val_sparse_categorical_accuracy: 0.8259 - val_student_loss: 1.4643 - lr: 1.0000e-05
# Epoch 53/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8928 - student_loss: 0.3124 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8248 - val_student_loss: 1.4677 - lr: 1.0000e-05
# Epoch 54/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.
100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.8933 - student_loss: 0.3109 - Dist_loss: 0.0030 - loss: 0.0338 - val_sparse_categorical_accuracy: 0.8257 - val_student_loss: 1.4682 - lr: 1.0000e-06
# Epoch 71/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.8924 - student_loss: 0.3136 - Dist_loss: 0.0030 - loss: 0.0341 - val_sparse_categorical_accuracy: 0.8260 - val_student_loss: 1.4634 - lr: 1.0000e-06
# Epoch 72/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8926 - student_loss: 0.3108 - Dist_loss: 0.0030 - loss: 0.0338 - val_sparse_categorical_accuracy: 0.8262 - val_student_loss: 1.4671 - lr: 1.0000e-06
# Epoch 73/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8923 - student_loss: 0.3135 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8252 - val_student_loss: 1.4678 - lr: 1.0000e-06
# Epoch 74/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.3138 - Dist_loss: 0.0030 - loss: 0.0341 - val_sparse_categorical_accuracy: 0.8246 - val_student_loss: 1.4665 - lr: 1.0000e-06
# Epoch 75/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8934 - student_loss: 0.3114 - Dist_loss: 0.0030 - loss: 0.0338 - val_sparse_categorical_accuracy: 0.8258 - val_student_loss: 1.4632 - lr: 1.0000e-06
# Epoch 76/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.3119 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8253 - val_student_loss: 1.4672 - lr: 1.0000e-06
# Epoch 77/100
# 1562/1562 [==============================] - 72s 46ms/step - sparse_categorical_accuracy: 0.8933 - student_loss: 0.3126 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8256 - val_student_loss: 1.4696 - lr: 1.0000e-06
# Epoch 78/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.3128 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8247 - val_student_loss: 1.4678 - lr: 1.0000e-06
# Epoch 79/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8929 - student_loss: 0.3125 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8249 - val_student_loss: 1.4642 - lr: 1.0000e-06
# Epoch 80/100
# 1562/1562 [==============================] - 71s 46ms/step - sparse_categorical_accuracy: 0.8919 - student_loss: 0.3114 - Dist_loss: 0.0030 - loss: 0.0338 - val_sparse_categorical_accuracy: 0.8248 - val_student_loss: 1.4650 - lr: 1.0000e-06
# Epoch 81/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.3118 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8258 - val_student_loss: 1.4662 - lr: 1.0000e-06
# Epoch 82/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8919 - student_loss: 0.3124 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8260 - val_student_loss: 1.4654 - lr: 1.0000e-06
# Epoch 83/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8923 - student_loss: 0.3130 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8255 - val_student_loss: 1.4655 - lr: 1.0000e-06
# Epoch 84/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8933 - student_loss: 0.3126 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8251 - val_student_loss: 1.4680 - lr: 1.0000e-06
# Epoch 85/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.3100 - Dist_loss: 0.0030 - loss: 0.0337 - val_sparse_categorical_accuracy: 0.8256 - val_student_loss: 1.4656 - lr: 1.0000e-06
# Epoch 86/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.3106 - Dist_loss: 0.0030 - loss: 0.0338 - val_sparse_categorical_accuracy: 0.8263 - val_student_loss: 1.4654 - lr: 1.0000e-06
# Epoch 87/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8919 - student_loss: 0.3131 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8259 - val_student_loss: 1.4650 - lr: 1.0000e-06
# Epoch 88/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8919 - student_loss: 0.3134 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8254 - val_student_loss: 1.4653 - lr: 1.0000e-06
# Epoch 89/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8924 - student_loss: 0.3122 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8253 - val_student_loss: 1.4667 - lr: 1.0000e-06
# Epoch 90/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8926 - student_loss: 0.3134 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8247 - val_student_loss: 1.4640 - lr: 1.0000e-06
# Epoch 91/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8935 - student_loss: 0.3101 - Dist_loss: 0.0030 - loss: 0.0337 - val_sparse_categorical_accuracy: 0.8259 - val_student_loss: 1.4649 - lr: 1.0000e-06
# Epoch 92/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8939 - student_loss: 0.3119 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8252 - val_student_loss: 1.4643 - lr: 1.0000e-06
# Epoch 93/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.3129 - Dist_loss: 0.0030 - loss: 0.0340 - val_sparse_categorical_accuracy: 0.8246 - val_student_loss: 1.4649 - lr: 1.0000e-06
# Epoch 94/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8932 - student_loss: 0.3107 - Dist_loss: 0.0030 - loss: 0.0338 - val_sparse_categorical_accuracy: 0.8255 - val_student_loss: 1.4659 - lr: 1.0000e-06
# Epoch 95/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8941 - student_loss: 0.3124 - Dist_loss: 0.0030 - loss: 0.0339 - val_sparse_categorical_accuracy: 0.8256 - val_student_loss: 1.4661 - lr: 1.0000e-06
# Epoch 96/100
# 1562/1562 [==============================] - 70s 45ms/step - sparse_categorical_accuracy: 0.8915 - student_loss: 0.3140 - Dist_loss: 0.0030 - loss: 0.0341 - val_sparse_categorical_accuracy: 0.8258 - val_student_loss: 1.4643 - lr: 1.0000e-06
# Epoch 97/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8925 - student_loss: 0.3152 - Dist_loss: 0.0030 - loss: 0.0342 - val_sparse_categorical_accuracy: 0.8247 - val_student_loss: 1.4667 - lr: 1.0000e-06
# Epoch 98/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8931 - student_loss: 0.3143 - Dist_loss: 0.0030 - loss: 0.0341 - val_sparse_categorical_accuracy: 0.8247 - val_student_loss: 1.4684 - lr: 1.0000e-06
# Epoch 99/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8949 - student_loss: 0.3096 - Dist_loss: 0.0030 - loss: 0.0337 - val_sparse_categorical_accuracy: 0.8251 - val_student_loss: 1.4657 - lr: 1.0000e-06
# Epoch 100/100
# 1562/1562 [==============================] - 71s 45ms/step - sparse_categorical_accuracy: 0.8912 - student_loss: 0.3114 - Dist_loss: 0.0030 - loss: 0.0338 - val_sparse_categorical_accuracy: 0.8259 - val_student_loss: 1.4662 - lr: 1.0000e-06
# 313/313 [==============================] - 4s 13ms/step - sparse_categorical_accuracy: 0.8259 - student_loss: 1.5782
#
#  =============== History Plot ===============
# Saving model
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Resnet8_kd_alpha_0.1_temp_100/assets
# Saving Done !
# Saving Weights
# Saving Done !
#
# End !
